# %% [markdown]
# # Get data
#
# get finance data...
#
# ## Historic
#
# **yahoo finance**
# * can do it..
#
#
# ## Real time
#
# [findings]

# %% [markdown]
# ## Quandl

# %% [markdown]
# ### Yahoo Finance

# %%
import yfinance as yf

# %%
test = yf.Ticker("AAPL")

# %%
dir(test)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_balancesheet',
#  '_base_url',
#  '_calendar',
#  '_cashflow',
#  '_download_options',
#  '_earnings',
#  '_expirations',
#  '_financials',
#  '_fundamentals',
#  '_get_fundamentals',
#  '_history',
#  '_info',
#  '_institutional_holders',
#  '_isin',
#  '_major_holders',
#  '_mutualfund_holders',
#  '_options2df',
#  '_recommendations',
#  '_scrape_url',
#  '_sustainability',
#  'actions',
#  'balance_sheet',
#  'balancesheet',
#  'calendar',
#  'cashflow',
#  'dividends',
#  'earnings',
#  'financials',
#  'get_actions',
#  'get_balance_sheet',
# ...

# %%
test = yf.download(tickers=['AAPL'],period='5m', interval='1m')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
test
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2021-06-18 15:55:00-04:00  130.710007  130.847305  130.639999  130.744995
# 2021-06-18 15:56:00-04:00  130.750000  130.779999  130.669998  130.684998
# 2021-06-18 15:57:00-04:00  130.684998  130.690002  130.610001  130.679993
# 2021-06-18 15:58:00-04:00  130.677505  130.719894  130.639999  130.649994
# 2021-06-18 15:59:00-04:00  130.669998  130.679993  130.240005  130.399994
#
#                             Adj Close   Volume
# Datetime
# 2021-06-18 15:55:00-04:00  130.744995        0
# 2021-06-18 15:56:00-04:00  130.684998   511871
# 2021-06-18 15:57:00-04:00  130.679993   479251
# 2021-06-18 15:58:00-04:00  130.649994   657943
# 2021-06-18 15:59:00-04:00  130.399994  1750713

# %%
test.shape
# Out:
# (5, 6)

# %%
test.index[1]
# Out:
# Timestamp('2021-06-18 15:56:00-0400', tz='America/New_York')

# %%
test_again = yf.download(tickers=['AAPL', 'GOOG'],period='5m',interval='1m')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
test_again
# Out:
#                             Adj Close                    Close               \
#                                  AAPL         GOOG        AAPL         GOOG
# Datetime
# 2021-06-18 15:55:00-04:00  130.744995  2518.770020  130.744995  2518.770020
# 2021-06-18 15:56:00-04:00  130.684998  2520.399902  130.684998  2520.399902
# 2021-06-18 15:57:00-04:00  130.679993  2515.810059  130.679993  2515.810059
# 2021-06-18 15:58:00-04:00  130.649994  2516.280029  130.649994  2516.280029
# 2021-06-18 15:59:00-04:00  130.399994  2511.340088  130.399994  2511.340088
#
#                                  High                      Low               \
#                                  AAPL         GOOG        AAPL         GOOG
# Datetime
# 2021-06-18 15:55:00-04:00  130.847305  2524.715088  130.639999  2518.770020
# 2021-06-18 15:56:00-04:00  130.779999  2521.090088  130.669998  2518.975098
# 2021-06-18 15:57:00-04:00  130.690002  2520.495117  130.610001  2515.330078
# ...

# %%
test_again.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close', 'GOOG'),
#             (    'Close', 'AAPL'),
#             (    'Close', 'GOOG'),
#             (     'High', 'AAPL'),
#             (     'High', 'GOOG'),
#             (      'Low', 'AAPL'),
#             (      'Low', 'GOOG'),
#             (     'Open', 'AAPL'),
#             (     'Open', 'GOOG'),
#             (   'Volume', 'AAPL'),
#             (   'Volume', 'GOOG')],
#            )

# %%
test.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...
